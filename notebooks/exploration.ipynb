# %% [markdown]
# # Exploration Notebook
# Use this notebook for exploratory analysis only.

# %%
import pandas as pd
from pathlib import Path

processed = Path('data/processed')
print('Processed path exists:', processed.exists())
